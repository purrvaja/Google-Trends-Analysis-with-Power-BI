# %% [markdown]
# <a href="https://colab.research.google.com/github/purrvaja/Google-Trends-Analysis-with-Power-BI/blob/main/google_trends_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading pytrends-4.9.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.10/dist-packages (from pytrends) (2.31.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from pytrends) (2.0.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pytrends) (4.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.16.0)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.9.2

# %%
import pandas as pd
import numpy as np

from pytrends.request import TrendReq

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import time
import math

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
keywords_list = [
    "Machine Learning",
    "Deep Learning",
    "Natural Language Processing",
    "Computer Vision",
    "Robotics",
    "Big Data",
    "Algorithm",
    "Neural Networks",
    "Artificial General Intelligence (AGI)",
    "Explainable AI (XAI)",
    "Reinforcement Learning",
    "Chatbots",
    "Generative AI",
    "Predictive Analytics",
    "AI Ethics"
]

# %%
# initialize a new Google Trends Request Object

pt = TrendReq(hl='en-US', tz=360)

# %%
# setting the time interval in between each api call
# using a higher time interval to avoid the response code 429

time_interval = 60

# %% [markdown]
# ## Interest over time

# %%
def interest_over_time(keywords_list, pt):
    result_df = pd.DataFrame(columns=['keyword', 'date', 'volume'])

    # Loop through each keyword
    for index, keyword in enumerate(keywords_list):

        # print a progress message
        print("=" * 25, str(index+1) + '.', "Processing =>", keyword, "=" * 25, "\n")


        # Set the keyword & timeframe for the current month
        try:
            pt.build_payload([keyword], cat=0, timeframe='all')

            # Get the interest over time
            iot = pt.interest_over_time()
            iot.reset_index(inplace=True)

            # Add the columns
            iot['keyword'] = keyword
            iot['volume'] = iot[keyword]

            # Appending the results to the main DataFrame
            result_df = pd.concat([result_df, iot[['date', 'keyword', 'volume']]], ignore_index=True)

        except Exception as e:
            print("Error when working on", keyword, "=>", e)


        # print progress message
        print("=" * 25, str(math.ceil(((index + 1) / len(keywords_list)) * 100))+"%", "Completed =>", keyword, "=" * 25, "\n")

        if index != len(keywords_list)-1:
            time.sleep(time_interval)

    # Convert the 'date' column to datetime format
    result_df['date'] = pd.to_datetime(result_df['date'])

    # Format the 'date' column to YYYY-MM
    result_df['date'] = result_df['date'].dt.strftime('%Y-%m')

    return result_df


# calling the function
iot_df = interest_over_time(keywords_list, pt)
# Out:
# ========================= 1. Processing => Machine Learning =========================
#
# ========================= 7% Completed => Machine Learning =========================
#
# ========================= 2. Processing => Deep Learning =========================
#
# ========================= 14% Completed => Deep Learning =========================
#
# ========================= 3. Processing => Natural Language Processing =========================
#
# ========================= 20% Completed => Natural Language Processing =========================
#
# ========================= 4. Processing => Computer Vision =========================
#
# ========================= 27% Completed => Computer Vision =========================
#
# ========================= 5. Processing => Robotics =========================
#
# ========================= 34% Completed => Robotics =========================
#
# ========================= 6. Processing => Big Data =========================
#
# ========================= 40% Completed => Big Data =========================
#
# ========================= 7. Processing => Algorithm =========================
#
# ========================= 47% Completed => Algorithm =========================
#
# ========================= 8. Processing => Neural Networks =========================
#
# ========================= 54% Completed => Neural Networks =========================
#
# ========================= 9. Processing => Artificial General Intelligence (AGI) =========================
#
# ========================= 60% Completed => Artificial General Intelligence (AGI) =========================
#
# ========================= 10. Processing => Explainable AI (XAI) =========================
#
# ========================= 67% Completed => Explainable AI (XAI) =========================
#
# ========================= 11. Processing => Reinforcement Learning =========================
#
# ========================= 74% Completed => Reinforcement Learning =========================
#
# ========================= 12. Processing => Chatbots =========================
#
# ========================= 80% Completed => Chatbots =========================
#
# ========================= 13. Processing => Generative AI =========================
#
# ========================= 87% Completed => Generative AI =========================
#
# ========================= 14. Processing => Predictive Analytics =========================
#
# ========================= 94% Completed => Predictive Analytics =========================
#
# ========================= 15. Processing => AI Ethics =========================
#
# ========================= 100% Completed => AI Ethics =========================

# %%
iot_df.head(10)
# Out:
#             keyword     date volume
# 0  Machine Learning  2004-01     13
# 1  Machine Learning  2004-02     13
# 2  Machine Learning  2004-03     13
# 3  Machine Learning  2004-04     14
# 4  Machine Learning  2004-05     13
# 5  Machine Learning  2004-06     13
# 6  Machine Learning  2004-07     10
# 7  Machine Learning  2004-08     11
# 8  Machine Learning  2004-09     13
# 9  Machine Learning  2004-10     12

# %%
# identify the ones that weren't captured in the first run. create a new list with those and run again. append the datafrmaes

# %% [markdown]
# ## Interest by region

# %%
def interest_by_region(keywords_list, pt):
    result_df = pd.DataFrame(columns=['country', 'keyword', 'volume'])

    # Loop through each keyword
    for index, keyword in enumerate(keywords_list):
        print("=" * 25, str(index+1) + '.', "Processing =>", keyword, "=" * 25, "\n")

        # Set the keyword & timeframe for the current month
        try:
            pt.build_payload([keyword], cat=0, timeframe='all')

            # Get the interest by region
            ibr = pt.interest_by_region(resolution='COUNTRY')
            ibr.reset_index(inplace=True)

            # Adding the columns
            ibr['country'] = ibr['geoName']
            ibr['keyword'] = keyword
            ibr['volume'] = ibr[keyword]

            # Appending the results to the main DataFrame
            result_df = pd.concat([result_df, ibr[['country', 'keyword', 'volume']]], ignore_index=True)

        except Exception as e:
            print("Error when working on", keyword, "=>", e)


        # print progress message
        print("=" * 25, str(math.ceil(((index + 1) / len(keywords_list)) * 100))+"%", "Completed =>", keyword, "=" * 25, "\n")

        if index != len(keywords_list)-1:
            time.sleep(time_interval)

    return result_df


# calling the function
ibr_df = interest_by_region(keywords_list, pt)
# Out:
# ========================= 1. Processing => Machine Learning =========================
#
# ========================= 7% Completed => Machine Learning =========================
#
# ========================= 2. Processing => Deep Learning =========================
#
# ========================= 14% Completed => Deep Learning =========================
#
# ========================= 3. Processing => Natural Language Processing =========================
#
# ========================= 20% Completed => Natural Language Processing =========================
#
# ========================= 4. Processing => Computer Vision =========================
#
# ========================= 27% Completed => Computer Vision =========================
#
# ========================= 5. Processing => Robotics =========================
#
# ========================= 34% Completed => Robotics =========================
#
# ========================= 6. Processing => Big Data =========================
#
# ========================= 40% Completed => Big Data =========================
#
# ========================= 7. Processing => Algorithm =========================
#
# ========================= 47% Completed => Algorithm =========================
#
# ========================= 8. Processing => Neural Networks =========================
#
# ========================= 54% Completed => Neural Networks =========================
#
# ========================= 9. Processing => Artificial General Intelligence (AGI) =========================
#
# ========================= 60% Completed => Artificial General Intelligence (AGI) =========================
#
# ========================= 10. Processing => Explainable AI (XAI) =========================
#
# ========================= 67% Completed => Explainable AI (XAI) =========================
#
# ========================= 11. Processing => Reinforcement Learning =========================
#
# ========================= 74% Completed => Reinforcement Learning =========================
#
# ========================= 12. Processing => Chatbots =========================
#
# ========================= 80% Completed => Chatbots =========================
#
# ========================= 13. Processing => Generative AI =========================
#
# ========================= 87% Completed => Generative AI =========================
#
# ========================= 14. Processing => Predictive Analytics =========================
#
# ========================= 94% Completed => Predictive Analytics =========================
#
# ========================= 15. Processing => AI Ethics =========================
#
# ========================= 100% Completed => AI Ethics =========================

# %%
ibr_df.head(10)
# Out:
#              country           keyword volume
# 0        Afghanistan  Machine Learning      0
# 1            Albania  Machine Learning      0
# 2            Algeria  Machine Learning     13
# 3     American Samoa  Machine Learning      0
# 4            Andorra  Machine Learning      0
# 5             Angola  Machine Learning      0
# 6           Anguilla  Machine Learning      0
# 7         Antarctica  Machine Learning      0
# 8  Antigua & Barbuda  Machine Learning      0
# 9          Argentina  Machine Learning      8

# %% [markdown]
# ## Related Topics

# %%
test_keywords_list = ['Deep Learning']
result_df = pd.DataFrame(columns = ['keyword', 'sub_keyword', 'topic_title', 'topic_type', 'value'])

# Loop through each keyword
for index, keyword in enumerate(test_keywords_list):
            print("=" * 25, str(index+1) + '.', "Processing =>", keyword, "=" * 25, "\n")

            # Set the keyword & timeframe for the current month
            try:
              pt.build_payload([keyword], cat=0, timeframe='all')


              # Get the related topics
              rt = pt.related_topics()

              # since this returns a 3-level nested dictionary, it needs to be wrangled and converted to a dataframe to proceed
              level2_keys = list(rt.get(keyword, {}).keys())

              level2_df = pd.DataFrame(columns = ['keyword', 'sub_keyword', 'topic_title', 'topic_type', 'value'])

              for l2_key in level2_keys:
                l2_df = rt.get(keyword, {}).get(l2_key, {})
                l2_df['keyword'] = keyword
                l2_df['sub_keyword'] = l2_key

                #l2_df = [['keyword', 'sub_keyword', 'topic_title', 'topic_type', 'value']]

                # append to the level 2 dataframe
                level2_df = pd.concat([level2_df, l2_df], ignore_index=True)



              # Appending the results to the main DataFrame
              result_df = pd.concat([result_df, level2_df], ignore_index=True)


            except Exception as e:
              print("Error when working on", keyword, "=>", e)

            print("=" * 25, str(math.ceil(((index + 1) / len(test_keywords_list)) * 100))+"%", "Completed =>", keyword, "=" * 25, "\n")

            if index != len(test_keywords_list)-1:
              time.sleep(time_interval)
# Out:
# ========================= 1. Processing => Deep Learning =========================
#
# ========================= 100% Completed => Deep Learning =========================

# %%
result_df
# Out:
#          keyword sub_keyword topic_title topic_type   value formattedValue  \
# 0  Deep Learning      rising        deep      Topic  241000       Breakout
# 1  Deep Learning      rising       Keras   Software  166000       Breakout
# 2  Deep Learning         top      Neuron      Topic     100            100
# 3  Deep Learning         top        deep      Topic      67             67
# 4  Deep Learning         top       Keras   Software      46             46
#
#                                        link      topic_mid hasData
# 0   /trends/explore?q=/g/120z94sp_&date=all   /g/120z94sp_     NaN
# 1  /trends/explore?q=/g/11c1r2rvnp&date=all  /g/11c1r2rvnp     NaN
# 2       /trends/explore?q=/m/059bs&date=all       /m/059bs    True
# 3   /trends/explore?q=/g/120z94sp_&date=all   /g/120z94sp_    True
# 4  /trends/explore?q=/g/11c1r2rvnp&date=all  /g/11c1r2rvnp    True

# %%
result_df
# Out:
#              keyword sub_keyword                 topic_title  \
# 0   Machine Learning      rising               Deep learning
# 1   Machine Learning      rising                Data science
# 2   Machine Learning      rising                    Engineer
# 3   Machine Learning      rising                    Coursera
# 4   Machine Learning      rising             Microsoft Azure
# 5   Machine Learning      rising                  TensorFlow
# 6   Machine Learning      rising                      GitHub
# 7   Machine Learning      rising                   Analytics
# 8   Machine Learning      rising                scikit-learn
# 9   Machine Learning      rising             Cloud computing
# 10  Machine Learning      rising                    Big data
# 11  Machine Learning      rising                      GitHub
# 12  Machine Learning      rising         Amazon Web Services
# 13  Machine Learning      rising              Google Scholar
# 14  Machine Learning      rising                   Andrew Ng
# 15  Machine Learning      rising                   Linearity
# 16  Machine Learning      rising         Stanford University
# 17  Machine Learning      rising               Certification
# 18  Machine Learning      rising                  Internship
# 19  Machine Learning      rising          Internet of things
# 20  Machine Learning      rising                      Python
# 21  Machine Learning      rising                    Learning
# 22  Machine Learning      rising     Artificial intelligence
# 23  Machine Learning         top            Machine learning
# 24  Machine Learning         top                    Learning
# 25  Machine Learning         top                     Machine
# 26  Machine Learning         top                    Learning
# 27  Machine Learning         top     Artificial intelligence
# 28  Machine Learning         top                        Data
# 29  Machine Learning         top                      Python
# 30  Machine Learning         top                   Algorithm
# 31  Machine Learning         top                Intelligence
# 32  Machine Learning         top               Deep learning
# 33  Machine Learning         top                      Course
# 34  Machine Learning         top                     Science
# 35  Machine Learning         top                  Prediction
# 36  Machine Learning         top                Data science
# 37  Machine Learning         top         Regression analysis
# 38  Machine Learning         top                     Project
# 39  Machine Learning         top  Statistical classification
# 40  Machine Learning         top                      System
# 41  Machine Learning         top                    Analysis
# 42  Machine Learning         top                    Data set
# 43  Machine Learning         top              Neural network
# 44  Machine Learning         top                    Engineer
# 45  Machine Learning         top        Application software
# 46  Machine Learning         top                    Coursera
#
#                                     topic_type   value formattedValue  \
# 0                                        Topic  381450       Breakout
# 1                               Field of study  304650       Breakout
# 2                                       Degree  213850       Breakout
# 3                                  Corporation  166750       Breakout
# 4                         Computer application  146800       Breakout
# 5                                     Software  137700       Breakout
# 6                             Software company  133400       Breakout
# 7                                        Topic  130050       Breakout
# 8                             Computer program  127300       Breakout
# 9                                        Topic  109250       Breakout
# 10                                       Topic  107250       Breakout
# 11                       Downloadable software   99300       Breakout
# 12                                    Web site   82250       Breakout
# 13                                    Web site   78850       Breakout
# 14         British-American computer scientist   77900       Breakout
# 15                                       Topic   69850       Breakout
# 16  Private university in Stanford, California   69550       Breakout
# 17                                       Topic   68450       Breakout
# 18                                       Topic   65350       Breakout
# 19                                       Topic   63800       Breakout
# 20                        Programming language    5250       Breakout
# 21                                       Topic    1800        +1,800%
# 22                              Field of study     400          +400%
# 23                              Field of study     100            100
# 24                                       Topic      79             79
# 25                                       Topic      74             74
# 26                                       Topic      20             20
# 27                              Field of study      20             20
# 28                                       Topic      11             11
# 29                        Programming language       7              7
# 30                                       Topic       6              6
# 31                                       Topic       4              4
# 32                                       Topic       4              4
# 33                                   Education       4              4
# 34                         Branch of knowledge       4              4
# 35                                       Topic       3              3
# 36                              Field of study       3              3
# 37                                       Topic       3              3
# 38                                       Topic       3              3
# 39                                       Topic       3              3
# 40                                       Topic       2              2
# 41                                       Topic       2              2
# 42                                       Topic       2              2
# 43                            Machine learning       2              2
# 44                                      Degree       2              2
# 45                     Software classification       2              2
# 46                                 Corporation       2              2
#
#                                         link      topic_mid hasData
# 0      /trends/explore?q=/m/0h1fn8h&date=all     /m/0h1fn8h     NaN
# 1      /trends/explore?q=/m/0jt3_q3&date=all     /m/0jt3_q3     NaN
# 2        /trends/explore?q=/m/09j9h&date=all       /m/09j9h     NaN
# 3      /trends/explore?q=/m/0j9kbbz&date=all     /m/0j9kbbz     NaN
# 4      /trends/explore?q=/m/04y7lrx&date=all     /m/04y7lrx     NaN
# 5   /trends/explore?q=/g/11bwp1s2k3&date=all  /g/11bwp1s2k3     NaN
# 6      /trends/explore?q=/m/0ryppmg&date=all     /m/0ryppmg     NaN
# 7       /trends/explore?q=/m/02gcn9&date=all      /m/02gcn9     NaN
# 8      /trends/explore?q=/m/0h97pvq&date=all     /m/0h97pvq     NaN
# 9      /trends/explore?q=/m/02y_9m3&date=all     /m/02y_9m3     NaN
# 10     /trends/explore?q=/m/0bs2j8q&date=all     /m/0bs2j8q     NaN
# 11     /trends/explore?q=/m/04g0kcw&date=all     /m/04g0kcw     NaN
# 12      /trends/explore?q=/m/05nrgx&date=all      /m/05nrgx     NaN
# 13      /trends/explore?q=/m/057mg4&date=all      /m/057mg4     NaN
# 14     /trends/explore?q=/m/062sdp4&date=all     /m/062sdp4     NaN
# 15       /trends/explore?q=/m/0mrtk&date=all       /m/0mrtk     NaN
# 16       /trends/explore?q=/m/06pwq&date=all       /m/06pwq     NaN
# 17    /trends/explore?q=/m/011b7yqg&date=all    /m/011b7yqg     NaN
# 18      /trends/explore?q=/m/01rk91&date=all      /m/01rk91     NaN
# 19     /trends/explore?q=/m/02vnd10&date=all     /m/02vnd10     NaN
# 20       /trends/explore?q=/m/05z1_&date=all       /m/05z1_     NaN
# 21    /trends/explore?q=/g/120vhg3f&date=all    /g/120vhg3f     NaN
# 22        /trends/explore?q=/m/0mkz&date=all        /m/0mkz     NaN
# 23      /trends/explore?q=/m/01hyh_&date=all      /m/01hyh_    True
# 24      /trends/explore?q=/m/0191f8&date=all      /m/0191f8    True
# 25       /trends/explore?q=/m/0dkw5&date=all       /m/0dkw5    True
# 26    /trends/explore?q=/g/120vhg3f&date=all    /g/120vhg3f    True
# 27        /trends/explore?q=/m/0mkz&date=all        /m/0mkz    True
# 28       /trends/explore?q=/m/026sq&date=all       /m/026sq    True
# 29       /trends/explore?q=/m/05z1_&date=all       /m/05z1_    True
# 30        /trends/explore?q=/m/0jpv&date=all        /m/0jpv    True
# 31      /trends/explore?q=/m/02kwz2&date=all      /m/02kwz2    True
# 32     /trends/explore?q=/m/0h1fn8h&date=all     /m/0h1fn8h    True
# 33      /trends/explore?q=/m/07hs4p&date=all      /m/07hs4p    True
# 34       /trends/explore?q=/m/06mq7&date=all       /m/06mq7    True
# 35      /trends/explore?q=/m/01klyk&date=all      /m/01klyk    True
# 36     /trends/explore?q=/m/0jt3_q3&date=all     /m/0jt3_q3    True
# 37      /trends/explore?q=/m/03f9cn&date=all      /m/03f9cn    True
# 38      /trends/explore?q=/m/0156dy&date=all      /m/0156dy    True
# 39      /trends/explore?q=/m/05czq1&date=all      /m/05czq1    True
# 40       /trends/explore?q=/m/0bj6r&date=all       /m/0bj6r    True
# 41    /trends/explore?q=/g/121vr6rm&date=all    /g/121vr6rm    True
# 42       /trends/explore?q=/m/02cck&date=all       /m/02cck    True
# 43       /trends/explore?q=/m/05dhw&date=all       /m/05dhw    True
# 44       /trends/explore?q=/m/09j9h&date=all       /m/09j9h    True
# 45      /trends/explore?q=/m/02bj4k&date=all      /m/02bj4k    True
# 46     /trends/explore?q=/m/0j9kbbz&date=all     /m/0j9kbbz    True

# %%
def related_topics(keywords_list, pt):
    result_df = pd.DataFrame(columns=['keyword', 'sub_keyword', 'topic_title', 'topic_type', 'value'])

    # Loop through each keyword
    for index, keyword in enumerate(keywords_list):
        print("=" * 25, str(index+1) + '.', "Processing =>", keyword, "=" * 25, "\n")

        # Set the keyword & timeframe for the current month
        try:
            pt.build_payload([keyword], cat=0, timeframe='all')

            # Get the related topics
            rt = pt.related_topics()

            # since this returns a 3-level nested dictionary, it needs to be wrangled and converted to a dataframe to proceed
            level2_keys = list(rt.get(keyword, {}).keys())

            level2_df = pd.DataFrame(columns=['keyword', 'sub_keyword', 'topic_title', 'topic_type', 'value'])

            for l2_key in level2_keys:
                l2_data = rt.get(keyword, {}).get(l2_key, {})
                l2_data['keyword'] = keyword
                l2_data['sub_keyword'] = l2_key

                # Append to the level 2 dataframe
                level2_df = pd.concat([level2_df, pd.DataFrame(l2_data)], ignore_index=True)

            # Appending the results to the main DataFrame
            result_df = pd.concat([result_df, level2_df], ignore_index=True)

        except Exception as e:
            print("Error when working on", keyword, "=>", e)

        print("=" * 25, str(math.ceil(((index + 1) / len(keywords_list)) * 100)) + "%", "Completed =>", keyword, "=" * 25, "\n")

        if index != len(keywords_list) - 1:
            time.sleep(time_interval)

    return result_df



# calling the function
rt_df = related_topics(keywords_list, pt)
# Out:
# ========================= 1. Processing => Machine Learning =========================
#
# ========================= 7% Completed => Machine Learning =========================
#
# ========================= 2. Processing => Deep Learning =========================
#
# ========================= 14% Completed => Deep Learning =========================
#
# ========================= 3. Processing => Natural Language Processing =========================
#
# ========================= 20% Completed => Natural Language Processing =========================
#
# ========================= 4. Processing => Computer Vision =========================
#
# ========================= 27% Completed => Computer Vision =========================
#
# ========================= 5. Processing => Robotics =========================
#
# ========================= 34% Completed => Robotics =========================
#
# ========================= 6. Processing => Big Data =========================
#
# ========================= 40% Completed => Big Data =========================
#
# ========================= 7. Processing => Algorithm =========================
#
# ========================= 47% Completed => Algorithm =========================
#
# ========================= 8. Processing => Neural Networks =========================
#
# ========================= 54% Completed => Neural Networks =========================
#
# ========================= 9. Processing => Artificial General Intelligence (AGI) =========================
#
# ========================= 60% Completed => Artificial General Intelligence (AGI) =========================
#
# ========================= 10. Processing => Explainable AI (XAI) =========================
#
# ========================= 67% Completed => Explainable AI (XAI) =========================
#
# ========================= 11. Processing => Reinforcement Learning =========================
#
# ========================= 74% Completed => Reinforcement Learning =========================
#
# ========================= 12. Processing => Chatbots =========================
#
# ========================= 80% Completed => Chatbots =========================
#
# ========================= 13. Processing => Generative AI =========================
#
# ========================= 87% Completed => Generative AI =========================
#
# ========================= 14. Processing => Predictive Analytics =========================
#
# ========================= 94% Completed => Predictive Analytics =========================
#
# ========================= 15. Processing => AI Ethics =========================
#
# ========================= 100% Completed => AI Ethics =========================

# %%
rt_df.head(10)
# Out:
#             keyword sub_keyword      topic_title            topic_type  \
# 0  Machine Learning      rising    Deep learning                 Topic
# 1  Machine Learning      rising     Data science        Field of study
# 2  Machine Learning      rising         Engineer                Degree
# 3  Machine Learning      rising         Coursera           Corporation
# 4  Machine Learning      rising  Microsoft Azure  Computer application
# 5  Machine Learning      rising       TensorFlow              Software
# 6  Machine Learning      rising           GitHub      Software company
# 7  Machine Learning      rising        Analytics                 Topic
# 8  Machine Learning      rising     scikit-learn      Computer program
# 9  Machine Learning      rising  Cloud computing                 Topic
#
#     value formattedValue                                      link  \
# 0  381450       Breakout     /trends/explore?q=/m/0h1fn8h&date=all
# 1  304650       Breakout     /trends/explore?q=/m/0jt3_q3&date=all
# 2  213850       Breakout       /trends/explore?q=/m/09j9h&date=all
# 3  166750       Breakout     /trends/explore?q=/m/0j9kbbz&date=all
# 4  146800       Breakout     /trends/explore?q=/m/04y7lrx&date=all
# 5  137700       Breakout  /trends/explore?q=/g/11bwp1s2k3&date=all
# 6  133400       Breakout     /trends/explore?q=/m/0ryppmg&date=all
# 7  130050       Breakout      /trends/explore?q=/m/02gcn9&date=all
# 8  127300       Breakout     /trends/explore?q=/m/0h97pvq&date=all
# 9  109250       Breakout     /trends/explore?q=/m/02y_9m3&date=all
#
#        topic_mid hasData
# 0     /m/0h1fn8h     NaN
# 1     /m/0jt3_q3     NaN
# 2       /m/09j9h     NaN
# 3     /m/0j9kbbz     NaN
# 4     /m/04y7lrx     NaN
# 5  /g/11bwp1s2k3     NaN
# 6     /m/0ryppmg     NaN
# 7      /m/02gcn9     NaN
# 8     /m/0h97pvq     NaN
# 9     /m/02y_9m3     NaN

# %% [markdown]
# ## Saving the DataFrames

# %%
iot_df.to_csv('/content/gdrive/My Drive/interest_over_time.csv')
ibr_df.to_csv('/content/gdrive/My Drive/interest_by_region.csv')
rt_df.to_csv('/content/gdrive/My Drive/releated_topics.csv')
